# %% [markdown]
# # Viewing Data
# Be sure to use a capital V!
#
# Note that the View command is not yet supported in Jupyter R kernel.

# %%
library("tidyverse")
data(iris)
View(iris)
# Out:
# Error in View(iris): ‘View()’ not yet supported in the Jupyter R kernel
# Traceback:
#
# 1. View(iris)
# 2. stop(sQuote("View()"), " not yet supported in the Jupyter R kernel")

# %%
require(lattice)
example(histogram)
# Out:
# Loading required package: lattice
# hstgrm> require(stats)
#
# hstgrm> histogram( ~ height | voice.part, data = singer, nint = 17,
# hstgrm+           endpoints = c(59.5, 76.5), layout = c(2,4), aspect = 1,
# hstgrm+           xlab = "Height (inches)")
#
# hstgrm> histogram( ~ height | voice.part, data = singer,
# hstgrm+           xlab = "Height (inches)", type = "density",
# hstgrm+           panel = function(x, ...) {
# hstgrm+               panel.histogram(x, ...)
# hstgrm+               panel.mathdensity(dmath = dnorm, col = "black",
# hstgrm+                                 args = list(mean=mean(x),sd=sd(x)))
# hstgrm+           } )
# plot without title
# hstgrm> densityplot( ~ height | voice.part, data = singer, layout = c(2, 4),
# hstgrm+             xlab = "Height (inches)", bw = 5)
# plot without title
# plot without title

# %% [markdown]
# # Example 1: Scatter Plot

# %%
#Documentation about the trees sample file
?trees

# %%
#Load the sample data "trees" into a dataframe df
df <- trees
trees

# %%
library("tidyverse")
ggplot (df, aes (x=Girth, y=Volume)) + geom_point()

# %% [markdown]
# # Example #2: Bar Chart (x)

# %%
mpg
?mpg

# %%
g <- ggplot (mpg, aes(class))

# %% [markdown]
# ### Note that no graph displays until you add the "Object to Draw" [in this case, geom_bar()]

# %%
g + geom_bar()

# %% [markdown]
# # Example #3: Bar Chart (x)

# %%
midwest
?midwest

# %%
ggplot (data=midwest, aes(x=state)) + geom_bar()

# %% [markdown]
# # Example #4: Importing CSV Data and Line Chart

# %%
library("tidyverse")
tsla_stock_metrics <- read_csv("https://www.sharpsightlabs.com/datasets/TSLA_start-to-2018-10-26_CLEAN.csv")
tsla_stock_metrics

# %%
ggplot(data=tsla_stock_metrics, aes(x=date,y=open_price))+geom_line()

# %% [markdown]
# # Example #5: Histogram

# %%
# Housing in Texas

ggplot(data = txhousing, aes(x = median)) + geom_histogram()

# %% [markdown]
# # Example #6: Density Plot

# %%
ggplot(data = txhousing, aes(x = median)) + geom_density()
